# %% [markdown]
# <a href="https://colab.research.google.com/github/leoanholetto1/Data-Science/blob/main/Tratamento_Base_Census.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install plotly --upgrade
# Out:
#      |████████████████████████████████| 15.3 MB 5.4 MB/s

# %%
import plotly.express as px
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
base_census = pd.read_csv('/content/census.csv')

# %%
base_census
# Out:
#        age          workclass  final-weight    education  education-num  \
# 0       39          State-gov         77516    Bachelors             13
# 1       50   Self-emp-not-inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 4       28            Private        338409    Bachelors             13
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# ...

# %%
base_census.describe()
# Out:
#                 age  final-weight  education-num  capital-gain  capital-loos  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hour-per-week
# count   32561.000000
# mean       40.437456
# std        12.347429
# min         1.000000
# 25%        40.000000
# 50%        40.000000
# 75%        45.000000
# max        99.000000

# %%
base_census.isnull().sum()
# Out:
# age               0
# workclass         0
# final-weight      0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loos      0
# hour-per-week     0
# native-country    0
# income            0
# dtype: int64

# %%
base_census['hour-per-week']
# Out:
# 0        40
# 1        13
# 2        40
# 3        40
# 4        40
#          ..
# 32556    38
# 32557    40
# 32558    40
# 32559    20
# 32560    40
# Name: hour-per-week, Length: 32561, dtype: int64

# %%
grafico = px.scatter_matrix(base_census , dimensions = ['age','hour-per-week'] , color = 'income')

# %%
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.countplot(x =base_census['income'])

# %%
np.unique(base_census['race'])
# Out:
# array([' Amer-Indian-Eskimo', ' Asian-Pac-Islander', ' Black', ' Other',
#        ' White'], dtype=object)

# %%
nova = base_census.loc[(base_census['age'] >20 ) & (base_census['age'] < 30 ) ]

# %%
sns.countplot(x =nova['income'])

# %%
np.unique(base_census['income'] , return_counts = True)
# Out:
# (array([' <=50K', ' >50K'], dtype=object), array([24720,  7841]))

# %%
sns.countplot(x = base_census['income'])

# %%
plt.hist(x = base_census['age'])
# Out:
# (array([5570., 5890., 6048., 6163., 3967., 2591., 1595.,  496.,  174.,
#           67.]),
#  array([17. , 24.3, 31.6, 38.9, 46.2, 53.5, 60.8, 68.1, 75.4, 82.7, 90. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x = base_census['education-num'])
# Out:
# (array([  219.,   333.,  1160.,   933.,  1608., 10501.,  8673.,  1067.,
#          7078.,   989.]),
#  array([ 1. ,  2.5,  4. ,  5.5,  7. ,  8.5, 10. , 11.5, 13. , 14.5, 16. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x = base_census['hour-per-week'])
# Out:
# (array([  736.,  2192.,  2317., 17735.,  3119.,  3877.,  1796.,   448.,
#           202.,   139.]),
#  array([ 1. , 10.8, 20.6, 30.4, 40.2, 50. , 59.8, 69.6, 79.4, 89.2, 99. ]),
#  <a list of 10 Patch objects>)

# %%
grafico = px.treemap(base_census, path = ['workclass','age'])

# %%
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico2 = px.treemap(base_census, path = ['age'])
grafico2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.treemap(base_census, path = ['occupation','relationship','age'])
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.parallel_categories(base_census, dimensions = ['occupation','relationship'])
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.parallel_categories(base_census, dimensions = ['workclass','occupation','relationship'])
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.parallel_categories(base_census, dimensions = ['education','income'])
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x_census = base_census.iloc[:, 0:14].values

# %%
x_census
# Out:
# array([[39, ' State-gov', 77516, ..., 0, 40, ' United-States'],
#        [50, ' Self-emp-not-inc', 83311, ..., 0, 13, ' United-States'],
#        [38, ' Private', 215646, ..., 0, 40, ' United-States'],
#        ...,
#        [58, ' Private', 151910, ..., 0, 40, ' United-States'],
#        [22, ' Private', 201490, ..., 0, 20, ' United-States'],
#        [52, ' Self-emp-inc', 287927, ..., 0, 40, ' United-States']],
#       dtype=object)

# %%
y_census = base_census.iloc[:, 14].values

# %%
y_census
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder_teste = LabelEncoder()

# %%
x_census[0]
# Out:
# array([39, ' State-gov', 77516, ' Bachelors', 13, ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', 2174, 0, 40,
#        ' United-States'], dtype=object)

# %%
x_census[:,1]
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ..., ' Private',
#        ' Private', ' Self-emp-inc'], dtype=object)

# %%
teste = label_encoder_teste.fit_transform(x_census[:,1])

# %%
teste
# Out:
# array([7, 6, 4, ..., 4, 4, 5])

# %%
type(x_census[0,1])
# Out:
# str

# %%
len(x_census[0])
# Out:
# 14

# %%
lista = []
for i in range(0,len(x_census[0])):
  if(type(x_census[0,i])==str):
    lista.append(i)

# %%
lista
# Out:
# [1, 3, 5, 6, 7, 8, 9, 13]

# %%
label_encoder_workclass = LabelEncoder()
label_encoder_education = LabelEncoder()
label_encoder_marital = LabelEncoder()
label_encoder_occupation = LabelEncoder()
label_encoder_relationship = LabelEncoder()
label_encoder_race = LabelEncoder()
label_encoder_sex = LabelEncoder()
label_encoder_country = LabelEncoder()

# %%
x_census[:,1] = label_encoder_workclass.fit_transform(x_census[:,1])
x_census[:,3] = label_encoder_education.fit_transform(x_census[:,3])
x_census[:,5] = label_encoder_marital.fit_transform(x_census[:,5])
x_census[:,6] = label_encoder_occupation.fit_transform(x_census[:,6])
x_census[:,7] = label_encoder_relationship.fit_transform(x_census[:,7])
x_census[:,8] = label_encoder_race.fit_transform(x_census[:,8])
x_census[:,9] = label_encoder_sex.fit_transform(x_census[:,9])
x_census[:,13] = label_encoder_country.fit_transform(x_census[:,13])

# %%
x2_census = x_census

# %%
x2_census
# Out:
# array([[39, ' State-gov', 77516, ..., 0, 40, ' United-States'],
#        [50, ' Self-emp-not-inc', 83311, ..., 0, 13, ' United-States'],
#        [38, ' Private', 215646, ..., 0, 40, ' United-States'],
#        ...,
#        [58, ' Private', 151910, ..., 0, 40, ' United-States'],
#        [22, ' Private', 201490, ..., 0, 20, ' United-States'],
#        [52, ' Self-emp-inc', 287927, ..., 0, 40, ' United-States']],
#       dtype=object)

# %%
label_encoder_vetor = []
for i in range(0,len(lista)):
  cria_obj = LabelEncoder()
  label_encoder_vetor.append(cria_obj)

for i in range(0,len(lista)):
  x2_census[:,lista[i]] = label_encoder_vetor[i].fit_transform(x_census[:,lista[i]])
x2_census
# Out:
# array([[39, 7, 77516, ..., 0, 40, 39],
#        [50, 6, 83311, ..., 0, 13, 39],
#        [38, 4, 215646, ..., 0, 40, 39],
#        ...,
#        [58, 4, 151910, ..., 0, 40, 39],
#        [22, 4, 201490, ..., 0, 20, 39],
#        [52, 5, 287927, ..., 0, 40, 39]], dtype=object)

# %%
x_census
# Out:
# array([[39, 7, 77516, ..., 0, 40, 39],
#        [50, 6, 83311, ..., 0, 13, 39],
#        [38, 4, 215646, ..., 0, 40, 39],
#        ...,
#        [58, 4, 151910, ..., 0, 40, 39],
#        [22, 4, 201490, ..., 0, 20, 39],
#        [52, 5, 287927, ..., 0, 40, 39]], dtype=object)

# %%
len(np.unique(base_census['workclass'])) #Primeiro elemento: 0 0 0 0 0 0 1 0 0
# Out:
# 9

# %%
len(np.unique(base_census['occupation']))
# Out:
# 15

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
x_census_aux = base_census.iloc[:, 0:14].values

# %%
onehotencoder_census = ColumnTransformer(transformers=[('OneHot', OneHotEncoder(), [1,3,5,6,7,8,9,13])], remainder='passthrough') #passthrough indica que não é pra apagar os atributos não usados

# %%
x_census = onehotencoder_census.fit_transform(x_census).toarray()

# %%
x_census
# Out:
# array([[0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 2.1740e+03, 0.0000e+00,
#         4.0000e+01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         1.3000e+01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         4.0000e+01],
#        ...,
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         4.0000e+01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         2.0000e+01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 1.5024e+04, 0.0000e+00,
#         4.0000e+01]])

# %%
onehotencoder_census2 = ColumnTransformer(transformers=[('OneHot', OneHotEncoder(), lista)], remainder='passthrough')

# %%
x2_census = onehotencoder_census2.fit_transform(x2_census).toarray()

# %%
x2_census
# Out:
# array([[0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 2.1740e+03, 0.0000e+00,
#         4.0000e+01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         1.3000e+01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         4.0000e+01],
#        ...,
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         4.0000e+01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         2.0000e+01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 1.5024e+04, 0.0000e+00,
#         4.0000e+01]])

# %%
x_census[0]
# Out:
# array([0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
# ...

# %%
x_census.shape
# Out:
# (32561, 108)

# %%
from sklearn.preprocessing import StandardScaler
scaler_census = StandardScaler()
x_census = scaler_census.fit_transform(x_census)

# %%
x_census[:1].max()
# Out:
# 4.907699683021048

# %%
x_census[:1].min()
# Out:
# -1.5167923045306437

# %%
x_census[0]
# Out:
# array([-0.2444502 , -0.17429511, -0.26209736, -0.01466381, -1.5167923 ,
#        -0.18838933, -0.29093568,  4.90769968, -0.02073999, -0.17175325,
#        -0.19348662, -0.11609195, -0.07201601, -0.10164955, -0.1422718 ,
#        -0.12664495, -0.18406376, -0.21053433,  2.25399324, -0.11334387,
#        -0.68994199, -0.23637391, -0.03960742, -0.13419553, -0.53714425,
#        -0.39750806, -0.02658695, -0.92284068, -0.11403678,  1.43105786,
#        -0.1802846 , -0.17735813, -0.24494366,  2.76348874, -0.01662771,
#        -0.37949517, -0.37774555, -0.17745022, -0.20957797, -0.25595432,
#        -0.33554133, -0.06780164, -0.38166338, -0.14260848, -0.35531609,
#        -0.17127887, -0.22710355, -0.82533335,  1.70899099, -0.17624972,
#        -0.42934582, -0.34403232, -0.22492681, -0.09820087, -0.18155194,
#        -0.32576824, -0.09161163,  0.4130197 , -0.70307135,  0.70307135,
#        -0.13502327, -0.02416321, -0.06107342, -0.0480488 , -0.04260602,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_census_treinamento , x_census_test , y_census_treinamento, y_census_test = train_test_split(x_census, y_census , test_size = 0.15 , random_state = 0) #random_state serve para deixar sempre a mesma base

# %%
x_census_treinamento.shape , y_census_treinamento.shape
# Out:
# ((27676, 108), (27676,))

# %%
x_census_test.shape , y_census_test.shape
# Out:
# ((4885, 108), (4885,))

# %%
import pickle
with open('census.pkl', mode = 'wb') as f:
  pickle.dump([x_census_treinamento,y_census_treinamento,x_census_test,y_census_test],f)
